# %% [raw]
# What is Pandas?
#     Pandas is a python module that makes data science easy and effective

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("D:/cricket dataset/all_season_bowling_card.csv")

# %%
df.head()
# Out:
#    season  match_id match_name home_team away_team bowling_team  \
# 0    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 1    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 2    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 3    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 4    2022   1304047  CSK v KKR       CSK       KKR          KKR
#
#                       venue    city country  innings_id  ... conceded wickets  \
# 0  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       20       2
# 1  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       35       0
# 2  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       23       1
# 3  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       15       0
# 4  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       38       1
#
#    economyRate  dots  foursConceded  sixesConceded wides  noballs  captain  \
# ...

# %%
df.shape
# Out:
# (11223, 24)

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'bowling_team', 'venue', 'city', 'country', 'innings_id', 'name',
#        'fullName', 'overs', 'maidens', 'conceded', 'wickets', 'economyRate',
#        'dots', 'foursConceded', 'sixesConceded', 'wides', 'noballs', 'captain',
#        'href'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11223, step=1)

# %%
df[df.isnull()]
# Out:
#        season  match_id match_name home_team away_team bowling_team venue  \
# 0         NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 1         NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 2         NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 3         NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 4         NaN       NaN        NaN       NaN       NaN          NaN   NaN
# ...       ...       ...        ...       ...       ...          ...   ...
# 11218     NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 11219     NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 11220     NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 11221     NaN       NaN        NaN       NaN       NaN          NaN   NaN
# 11222     NaN       NaN        NaN       NaN       NaN          NaN   NaN
#
#       city country  innings_id  ... conceded wickets  economyRate  dots  \
# ...

# %%
df.dropna()
# Out:
#        season  match_id match_name home_team away_team bowling_team  \
# 0        2022   1304047  CSK v KKR       CSK       KKR          KKR
# 1        2022   1304047  CSK v KKR       CSK       KKR          KKR
# 2        2022   1304047  CSK v KKR       CSK       KKR          KKR
# 3        2022   1304047  CSK v KKR       CSK       KKR          KKR
# 4        2022   1304047  CSK v KKR       CSK       KKR          KKR
# ...       ...       ...        ...       ...       ...          ...
# 11218    2008    336040   CSK v RR       CSK        RR          CSK
# 11219    2008    336040   CSK v RR       CSK        RR          CSK
# 11220    2008    336040   CSK v RR       CSK        RR          CSK
# 11221    2008    336040   CSK v RR       CSK        RR          CSK
# 11222    2008    336040   CSK v RR       CSK        RR          CSK
#
#                                     venue    city country  innings_id  ...  \
# ...

# %% [raw]
# Top 5 wicket taker in ipl :

# %%
df.groupby('name').sum().sort_values('wickets',ascending =False)['wickets'].head()
# Out:
# name
# DJ Bravo      183
# SL Malinga    170
# YS Chahal     166
# A Mishra      166
# R Ashwin      157
# Name: wickets, dtype: int64

# %%
w =  df.groupby('name').sum().sort_values('wickets',ascending =False)['wickets'].head().reset_index()
sns.barplot(x = 'name',y ='wickets',data =w,palette='coolwarm')
plt.tight_layout()
sns.despine()

# %%
df['season'].max()
# Out:
# 2022

# %% [raw]
# Top 5 runs conceded bowler in ipl :

# %%
df.groupby('name').sum().sort_values('conceded',ascending =False)['conceded'].head()
# Out:
# name
# R Ashwin           4534
# DJ Bravo           4360
# PP Chawla          4301
# RA Jadeja          4064
# Harbhajan Singh    4030
# Name: conceded, dtype: int64

# %% [raw]
# Top 5 most match played bowler

# %%
df.groupby('name')['match_id'].count().sort_values(ascending=False).head()
# Out:
# name
# R Ashwin           181
# RA Jadeja          181
# PP Chawla          164
# Harbhajan Singh    160
# DJ Bravo           158
# Name: match_id, dtype: int64

# %% [raw]
# DJ Bravo most wicket taken venue in ipl:

# %%
df[df['name']=='DJ Bravo'].groupby('venue').sum()['wickets'].sort_values(ascending =False).head(1)
# Out:
# venue
# MA Chidambaram Stadium, Chepauk, Chennai    44
# Name: wickets, dtype: int64

# %% [raw]
# DJ Bravo most wicket taken venue in ipl: city <> 'Chennai'

# %%
df[(df['name']=='DJ Bravo') & (df['city'] != 'Chennai')].groupby('venue').sum()['wickets'].sort_values(ascending =False).head(1)
# Out:
# venue
# Wankhede Stadium, Mumbai    26
# Name: wickets, dtype: int64

# %% [raw]
# Max and Min boundary conceded bolwer in ipl :

# %%
df['boundary'] = df['sixesConceded'] + df['foursConceded']

# %%
#Max :

df.groupby('name').sum()['boundary'].sort_values(ascending=False).head(1)
# Out:
# name
# UT Yadav    556
# Name: boundary, dtype: int64

# %%
#Min :

df.groupby('name').sum()['boundary'].sort_values().head(5)
# Out:
# name
# A Badoni        0
# DA Warner       0
# AM Rahane       0
# AC Gilchrist    0
# SS Iyer         1
# Name: boundary, dtype: int64

# %% [raw]
# Most six conceded bowler in 2022 :

# %%
df[df['season']==2022].groupby('name').sum().sort_values('sixesConceded',ascending =False).head(1)['sixesConceded']
# Out:
# name
# Mohammed Siraj    31
# Name: sixesConceded, dtype: int64

# %% [raw]
# Most six conceded bowler in ipl :

# %%
df.groupby('name').sum().sort_values('sixesConceded',ascending =False).head(1)['sixesConceded']
# Out:
# name
# PP Chawla    182
# Name: sixesConceded, dtype: int64

# %% [raw]
# How many season of ipl is played in away india:

# %%
df[df['country'] != 'India'].groupby(['season','country']).sum()
# Out:
#                               match_id  innings_id   overs  maidens  conceded  \
# season country
# 2009   South Africa          278469692        1066  2173.2       21     15944
# 2014   United Arab Emirates  170655720         349   764.8        8      5666
# 2020   United Arab Emirates  840369680        1034  2327.1       20     19070
# 2021   United Arab Emirates  443952078         530  1179.5        9      8994
#
#                              wickets  dots  foursConceded  sixesConceded  \
# season country
# 2009   South Africa              621  5385           1316            506
# 2014   United Arab Emirates      219  1829            464            173
# 2020   United Arab Emirates      625  5063           1582            734
# 2021   United Arab Emirates      352  2688            738            307
#
#                              wides  noballs  captain  boundary
# season country
# 2009   South Africa            437       73       41      1822
# ...

# %%
df[df['country'] != 'India']['country'].unique()
# Out:
# array(['United Arab Emirates', 'South Africa'], dtype=object)

# %% [raw]
# maximum economyRate of the blower in 2022:

# %%
df[df['season']==2022].groupby('name')['economyRate'].max().sort_values().head()
# Out:
# name
# Shashank Singh     10.0
# S Kaul            10.75
# S Gopal           11.33
# R Sanjay Yadav     11.5
# FA Allen           11.5
# Name: economyRate, dtype: object

# %% [raw]
# Purple cap holder in each season of ipl with No of wickets:

# %%
all_season_wicket = df.groupby(['season','name'])['wickets'].sum().reset_index()
all_season_wicket
# Out:
#       season               name  wickets
# 0       2008           A Kumble        7
# 1       2008           A Mishra       11
# 2       2008            A Nehra       12
# 3       2008              A Nel        1
# 4       2008          A Symonds        0
# ...      ...                ...      ...
# 1668    2022            VR Iyer        0
# 1669    2022  Washington Sundar        6
# 1670    2022        YBK Jaiswal        0
# 1671    2022          YS Chahal       27
# 1672    2022         Yash Dayal       11
#
# [1673 rows x 3 columns]

# %%
all_season_wicket.loc[all_season_wicket.groupby('season')['wickets'].idxmax()]
# Out:
#       season           name  wickets
# 84      2008  Sohail Tanvir       22
# 174     2009       RP Singh       23
# 284     2010        PP Ojha       21
# 447     2011     SL Malinga       28
# 537     2012       M Morkel       25
# 629     2013       DJ Bravo       32
# 779     2014      MM Sharma       23
# 847     2015       DJ Bravo       26
# 938     2016        B Kumar       23
# 1048    2017        B Kumar       26
# 1144    2018         AJ Tye       24
# 1269    2019    Imran Tahir       26
# 1381    2020       K Rabada       30
# 1467    2021       HV Patel       32
# 1671    2022      YS Chahal       27

# %%
cap = all_season_wicket.loc[all_season_wicket.groupby('season')['wickets'].idxmax()]
plt.figure(figsize=(12,4))
sns.barplot(x = 'name',y ='wickets',data =cap,palette='rainbow')
plt.tight_layout()
sns.despine()

# %% [raw]
# Most purple cap Won blower in Ipl :

# %%
all_season_wicket.loc[all_season_wicket.groupby('season')['wickets'].idxmax()].value_counts('name')
# Out:
# name
# B Kumar          2
# DJ Bravo         2
# AJ Tye           1
# HV Patel         1
# Imran Tahir      1
# K Rabada         1
# M Morkel         1
# MM Sharma        1
# PP Ojha          1
# RP Singh         1
# SL Malinga       1
# Sohail Tanvir    1
# YS Chahal        1
# dtype: int64

# %% [raw]
# Highest wicket taker in single match :

# %%
most_wicketin_single = df.groupby(['match_id','name'])['wickets'].sum().reset_index()
most_wicketin_single.loc[most_wicketin_single.groupby('match_id')['wickets'].idxmax()].sort_values('wickets',ascending = False)
# Out:
#        match_id           name  wickets
# 290      336005  Sohail Tanvir        6
# 8499    1178394      AS Joseph        6
# 6609     980979        A Zampa        6
# 456      336020       A Mishra        5
# 10827   1304086    Umran Malik        5
# ...         ...            ...      ...
# 5633     829735   Ankit Sharma        1
# 3363     548337      IK Pathan        1
# 5546     829721      CH Morris        1
# 2000     419156      IK Pathan        1
# 1071     392214      IK Pathan        1
#
# [950 rows x 3 columns]

# %% [raw]
# How many times 6 and 5 wickets taken in Ipl match :

# %%
(most_wicketin_single.loc[most_wicketin_single.groupby('match_id')['wickets'].idxmax()].value_counts('wickets')).sort_values().head(2)
# Out:
# wickets
# 6     3
# 5    25
# dtype: int64

# %%
df.head(2)
# Out:
#    season  match_id match_name home_team away_team bowling_team  \
# 0    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 1    2022   1304047  CSK v KKR       CSK       KKR          KKR
#
#                       venue    city country  innings_id  ... conceded wickets  \
# 0  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       20       2
# 1  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       35       0
#
#    economyRate  dots  foursConceded  sixesConceded wides  noballs  captain  \
# 0          5.0    15              1              1     2        1    False
# 1         8.75    12              3              2     1        1    False
#
#                                                 href
# 0  https://www.espncricinfo.com/ci/content/player...
# 1  https://www.espncricinfo.com/ci/content/player...
#
# [2 rows x 24 columns]

# %%
df['wickets'].sum()
# Out:
# 10108

# %% [raw]
# Season wise max wicket taker in single match :

# %%
year=df[['season','name','wickets','economy','maidens']]
year=year.sort_values('wickets').drop_duplicates('season',keep='last')
year.sort_values('season')
# Out:
#        season            name  wickets    economy  maidens
# 10816    2008   Sohail Tanvir        6   3.500000        0
# 9849     2009        A Kumble        5   1.612903        1
# 9536     2010        SK Warne        4   5.250000        0
# 8264     2011      SL Malinga        5   3.823529        1
# 7547     2012       SP Narine        5   4.750000        0
# 7246     2013     JP Faulkner        5   4.000000        1
# 6178     2014    Yuvraj Singh        4   8.750000        0
# 5532     2015        MA Starc        4   3.750000        0
# 4826     2016         A Zampa        6   4.750000        0
# 4160     2017      JD Unadkat        5   7.500000        1
# 3221     2018      AS Rajpoot        5   3.500000        0
# 2467     2019       AS Joseph        6   3.529412        1
# 2040     2020        CV Varun        5   5.000000        0
# 1179     2021  Arshdeep Singh        5   8.000000        0
# 351      2022       YS Chahal        5  10.000000        0

# %%
df[(df['season']==2022) & (df['wickets']==5)]
# Out:
#      season  match_id match_name home_team away_team bowling_team  \
# 351    2022   1304076   RR v KKR        RR       KKR           RR
# 463    2022   1304086   GT v SRH        GT       SRH          SRH
# 628    2022   1304100  SRH v RCB       SRH       RCB          RCB
# 642    2022   1304102   MI v KKR        MI       KKR           MI
#
#                                        venue         city country  innings_id  \
# 351                Brabourne Stadium, Mumbai       Mumbai   India           2
# 463                 Wankhede Stadium, Mumbai       Mumbai   India           2
# 628                 Wankhede Stadium, Mumbai       Mumbai   India           2
# 642  Dr DY Patil Sports Academy, Navi Mumbai  Navi Mumbai   India           1
#
#      ... conceded wickets  economyRate  dots  foursConceded  sixesConceded  \
# 351  ...       40       5         10.0     7              4              1
# 463  ...       25       5         6.25    12              4              0
# ...

# %%
year=df[['season','name','wickets','economy']].sort_values('wickets',ascending=False)
#year.loc[year.groupby(['season','name'])['wickets'].idxmax()]
year_f = year.sort_values(['wickets','economy']).drop_duplicates('season',keep='last')
year_f.sort_values('season')
# Out:
#        season             name  wickets    economy
# 10816    2008    Sohail Tanvir        6   3.500000
# 9849     2009         A Kumble        5   1.612903
# 9314     2010    R Vinay Kumar        4  10.000000
# 8860     2011         MM Patel        5   5.250000
# 7512     2012   AD Mascarenhas        5   6.250000
# 7124     2013       JD Unadkat        5   6.250000
# 6461     2014  Karanveer Singh        4  13.500000
# 5265     2015          D Wiese        4   8.250000
# 4826     2016          A Zampa        6   4.750000
# 4160     2017       JD Unadkat        5   7.500000
# 3221     2018       AS Rajpoot        5   3.500000
# 2467     2019        AS Joseph        6   3.529412
# 2040     2020         CV Varun        5   5.000000
# 1179     2021   Arshdeep Singh        5   8.000000
# 351      2022        YS Chahal        5  10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11223 entries, 0 to 11222
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         11223 non-null  int64
#  1   match_id       11223 non-null  int64
#  2   match_name     11223 non-null  object
#  3   home_team      11223 non-null  object
#  4   away_team      11223 non-null  object
#  5   bowling_team   11223 non-null  object
#  6   venue          11223 non-null  object
#  7   city           11223 non-null  object
#  8   country        11223 non-null  object
#  9   innings_id     11223 non-null  int64
#  10  name           11223 non-null  object
#  11  fullName       11223 non-null  object
#  12  overs          11223 non-null  float64
#  13  maidens        11223 non-null  int64
#  14  conceded       11223 non-null  int64
#  15  wickets        11223 non-null  int64
#  16  economyRate    11223 non-null  object
# ...

# %%
#Adding new column in dataframe df : 
df['economy'] = df['conceded']/df['overs']

# %%
df.head()
# Out:
#    season  match_id match_name home_team away_team bowling_team  \
# 0    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 1    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 2    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 3    2022   1304047  CSK v KKR       CSK       KKR          KKR
# 4    2022   1304047  CSK v KKR       CSK       KKR          KKR
#
#                       venue    city country  innings_id  ... wickets  \
# 0  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       2
# 1  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       0
# 2  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       1
# 3  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       0
# 4  Wankhede Stadium, Mumbai  Mumbai   India           1  ...       1
#
#   economyRate  dots  foursConceded  sixesConceded  wides noballs  captain  \
# 0         5.0    15              1              1      2       1    False
# ...

# %%
pd.set_option('display.max_columns',25)

# %% [raw]
# Find top 5 maiden over blowed player in IPL :

# %%
df.groupby(['season','fullName'])['maidens'].sum().sort_values(ascending=False).head()
# Out:
# season  fullName
# 2011    Praveen Kumar      5
# 2015    Sandeep Sharma     4
# 2013    Ravi Rampaul       4
# 2016    Dhawal Kulkarni    4
# 2022    Trent Boult        3
# Name: maidens, dtype: int64

# %% [raw]
# season wise highest maiden over :

# %%
den = df.groupby(['season','fullName'])['maidens'].sum().reset_index()
den_m = den.loc[den.groupby('season')['maidens'].idxmax()]
den_m
# Out:
#       season         fullName  maidens
# 46      2008    Manpreet Gony        3
# 151     2009   Lasith Malinga        2
# 233     2010    Chaminda Vaas        2
# 415     2011    Praveen Kumar        5
# 490     2012   Ben Hilfenhaus        2
# 692     2013     Ravi Rampaul        4
# 734     2014       Axar Patel        2
# 904     2015   Sandeep Sharma        4
# 953     2016  Dhawal Kulkarni        4
# 1077    2017   Jaydev Unadkat        3
# 1190    2018      Lungi Ngidi        2
# 1255    2019    Deepak Chahar        2
# 1430    2020      Trent Boult        3
# 1471    2021    Ishant Sharma        2
# 1627    2022  Prasidh Krishna        3

# %%
plt.figure(figsize=(18,7))
sns.barplot(x = 'fullName',y ='maidens',data =den_m,palette='rainbow')
plt.tight_layout()
sns.despine()

# %% [raw]
# Season wise runs conceded in ipl matches :

# %%
runs = df.groupby('season')['conceded'].sum().reset_index()
plt.figure(figsize=(12,4))
sns.barplot(x = 'season',y ='conceded',data =runs,palette='cividis')
plt.tight_layout()
sns.despine()
